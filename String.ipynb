# %%
#string
print("Hello python")
# Out:
# Hello python

# %%
print('Hello python')
# Out:
# Hello python

# %%
print("""Hello python""")
# Out:
# Hello python

# %%
print('''Hello python''')
# Out:
# Hello python

# %%
location="salem"
print(location)
# Out:
# salem

# %%
print(location[0])
print(location[1])
print(location[2])
print(location[3])
print(location[4])
#index / position - 0
#length - 1
# Out:
# s
# a
# l
# e
# m

# %%
location = "salem"

for i in location:
    print(i)
# Out:
# s
# a
# l
# e
# m

# %%
location = "salem"
print(len(location))
# Out:
# 5

# %%
content = "hello world"
print("python" in content)
# Out:
# False

# %%
content = "hello world"
print("hello" in content)
print("hi" not in content)
# Out:
# True
# True

# %%
content = "welcome to credo systemz"

if "AI" in content:
    print("AI is present")
else:
    print("AI is not present")
# Out:
# AI is not present

# %%
location = "salem"
print(location[2:4])

print(location[:4])
print(location[2:])
# Out:
# le
# sale
# lem

# %%
location = "salem"
print(location[-1])
print(location[-2])
# Out:
# m
# e

# %%
location = "salem"
print(location[-5:-2])
# Out:
# sal

# %%
location = "salem"
print(location.lower())
print(location.upper())
# Out:
# salem
# SALEM

# %%
location="          salem          "
print(location)
print(location.strip())
# Out:
#           salem
# salem

# %%
MSG = "call cat"
print(MSG.replace("cat","dog"))
# Out:
# call dog

# %%
msg = "python DA DS DV Power bi"

answer=msg.split(" ")
print(msg)

print(type(answer))
print(msg)

print(len(answer))
print(len(msg))
# Out:
# python DA DS DV Power bi
# <class 'list'>
# python DA DS DV Power bi
# 6
# 24

# %%
content="welcome to credo systemz"
answer=content.capitalize()
print(answer)

#converts the first character to upper case
# Out:
# Welcome to credo systemz

# %%
#casewhold() - converts string into lower case

content = "welcome to credo systemz"
answer = content.casefold()
print(answer)
# Out:
# welcome to credo systemz

# %%
content="credo systemz"
answer=content.center(20)
print(answer)
# Out:
#    credo systemz

# %%
content="credo systemz"
answer=content.center(20, "*")
print(answer)
# Out:
# ***credo systemz****

# %%
txt="I Love Python"
answer=txt.count("o")
print(answer)
# Out:
# 2

# %%
txt="I Love Python"
answer=txt.endswith("understand")
print(answer)
# Out:
# False

# %%
txt="I Love Python"
answer=txt.startswith("understand")
print(answer)
# Out:
# False

# %%
txt= "i love python, python is powerfull"

answer=txt.find("python")
print(answer)

answer=txt.index("python")
print(answer)
# Out:
# 7
# 7

# %%
txt="Password123"
answer=txt.isalnum()
print(answer)
# Out:
# True

# %%
txt="password"
answer=txt.isalpha()
print(answer)
# Out:
# True

# %%
txt="password"
answer=txt.islower()
print(answer)
# Out:
# True

# %%
txt="123"
ans=txt.isnumeric()
print(ans)
# Out:
# True

# %%
answer=("python","DA","DV","DS")

check=" ".join(answer)
print(check)

print(type(answer))
print(type(check))
# Out:
# python DA DV DS
# <class 'tuple'>
# <class 'str'>

# %%
txt="I Love Python"
answer=txt.replace("Love","like")
print(answer)
# Out:
# I like Python

# %%
S1="PYTHON"
S2="AI"

answer=S1+" " +S2
print(answer)
# Out:
# PYTHON AI

# %%
marks=80
#txt="anu - marks "+marks
txt=f"anu - python marks{marks}"
print(txt)
# Out:
# anu - python marks80
